# %% [markdown]
# <a href="https://colab.research.google.com/github/ArevaloMurguia/Mate-Razonamiento-Arevalo-Rafael-0031-/blob/main/Mate_p3_al_p5_Arevalo_Rafael_0031.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Arevalo Rafael NL = 3 NC = 2530805128**0031**
# #### Fecha:15/Abr/26
# #### ⛽ Problema 3:
# #### Enunciado:
# #### Un número que al restarle 7 da como resultado 18. ¿Cuál es ese número?
#
# #### 🧠 Planteamiento
# #### Sea x el número desconocido
# “Restarle 7” →
# 𝑥
# −
# 7
# x−7
# Resultado → 18
# #### 🧮 Ecuación
#
# 𝑥
# −
# 7
# =
# 18
# x−7=18
#
# #### ✏️ Despeje
#
# Sumamos 7 a ambos lados:
#
# 𝑥
# =
# 18
# +
# 7
# x=18+7
# 𝑥
# =
# 25
# x=25
# #### ✅ Resultado
#
# 👉 El número es 25

# %%
# Problema 3: Un número menos 7 es igual a 18
# x - 7 = 18

resultado = int(input("Ingrese el resultado: "))
numero_resta = int(input("Ingrese el número que se resta: "))

# Despeje: x = resultado + numero_resta
x = resultado + numero_resta

print(f"El número buscado es: {x}")
# Out:
# Ingrese el resultado: 18
# Ingrese el número que se resta: 7
# El número buscado es: 25

# %% [markdown]
# #### 🔹 Problema 4
# #### Enunciado:
# #### El triple de un número más cuatro es igual a 31.
#
# #### 🧠 Planteamiento
# #### Sea x el número
# Triple →
# 3
# 𝑥
# 3x
# Más 4 →
# 3
# 𝑥
# +
# 4
# 3x+4
# Resultado → 31
# #### 🧮 Ecuación
#
# 3
# 𝑥
# +
# 4
# =
# 31
# 3x+4=31
#
# #### ✏️ Despeje
#
# Restamos 4:
#
# 3
# 𝑥
# =
# 31
# −
# 4
# 3x=31−4
# 3
# 𝑥
# =
# 27
# 3x=27
#
# Dividimos entre 3:
#
# 𝑥
# =
# 9
# x=9
# #### ✅ Resultado
#
# 👉 El número es 9

# %%
# Problema 4: El triple de un número más 4 es igual a 31
# 3x + 4 = 31

resultado = int(input("Ingrese el resultado: "))
numero_suma = int(input("Ingrese el número que se suma: "))
coeficiente = int(input("Ingrese el coeficiente (triple = 3): "))

# Despeje: x = (resultado - numero_suma) / coeficiente
x = (resultado - numero_suma) / coeficiente

print(f"El número buscado es: {x}")
# Out:
# Ingrese el resultado: 31
# Ingrese el número que se suma: 4
# Ingrese el coeficiente (triple = 3): 3
# El número buscado es: 9.0

# %% [markdown]
# #### ⏰ Problema 5
# #### Enunciado:
# #### Un terreno tiene un largo que mide 5 metros más que el ancho. El perímetro total es 50 m.
#
# #### 🧠 Planteamiento
# #### Sea x el ancho
# Largo →
# 𝑥
# +
# 5
# x+5
# Perímetro de rectángulo →
# 2
# (
# 𝑙
# 𝑎
# 𝑟
# 𝑔
# 𝑜
# +
# 𝑎
# 𝑛
# 𝑐
# ℎ
# 𝑜
# )
# 2(largo+ancho)
# #### 🧮 Ecuación
#
# 2
# (
# 𝑥
# +
# (
# 𝑥
# +
# 5
# )
# )
# =
# 50
# 2(x+(x+5))=50
#
# #### ✏️ Despeje
# 2
# (
# 2
# 𝑥
# +
# 5
# )
# =
# 50
# 2(2x+5)=50
# 4
# 𝑥
# +
# 10
# =
# 50
# 4x+10=50
#
# Restamos 10:
#
# 4
# 𝑥
# =
# 40
# 4x=40
#
# Dividimos entre 4:
#
# 𝑥
# =
# 10
# x=10
# 📏 Medidas
# Ancho = 10 m
# Largo =
# 10
# +
# 5
# =
# 15
# 10+5=15 m
# #### ✅ Resultado
#
# 👉 El terreno mide:
#
# Ancho: 10 m
# Largo: 15 m

# %%
# Problema 5: Perímetro de un terreno
# 2(x + (x + 5)) = 50

perimetro = int(input("Ingrese el perímetro total: "))
diferencia = int(input("Ingrese cuánto mide de más el largo: "))

# Despeje: x = (perimetro - 2*diferencia) / 4
x = (perimetro - 2 * diferencia) / 4
largo = x + diferencia

print(f"El ancho es: {x} metros")
print(f"El largo es: {largo} metros")
# Out:
# Ingrese el perímetro total: 50
# Ingrese cuánto mide de más el largo: 5
# El ancho es: 10.0 metros
# El largo es: 15.0 metros
